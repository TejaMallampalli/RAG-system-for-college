# %% [markdown]
# # *DOCUMENT LOADING*

# %% [markdown]
# ## *Document Loading using PyPDFLoader*

# %% [markdown]
# ### *This step loads the R20 regulation PDF using PyPDFLoader. It reads all 22 pages and converts each page into LangChain Document object. This is the raw data source for our entire RAG pipeline.*

# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader(r"C:\Users\tejam\OneDrive\Desktop\AI Engineer\Final-B.-Tech-R20-REGULATIONS 30-09-2021.pdf")

# %%
document = loader.load()
data = str(document)

# %%
print(data)
