# %% [markdown]
# # *CHUNKING*

# %% [markdown]
# ## *Text Chunking / Splitting*

# %% [markdown]
# ### *Large pages are split into small chunks of 500 characters with 50 overlap. We cannot give a full page to embedding model, so chunking is needed. Chunk size 20 failed because it created too many small meaningless chunks.*

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size = 500,
    chunk_overlap = 50
)

# %%
chunks = splitter.split_text(data)

# %%
print(chunks)
