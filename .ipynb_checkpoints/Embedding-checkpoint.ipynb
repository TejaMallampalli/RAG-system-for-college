# %% [markdown]
# # *EMBEDDING*

# %% [markdown]
# ## *Embedding Generation*

# %% [markdown]
# ### *Here we convert text chunks into numerical vectors using nomic-embed-text model via Ollama. Vectors capture the semantic meaning of the text. Similar questions will have similar vectors, which helps in searching.*

# %%
from langchain_ollama import OllamaEmbeddings

# %%
embeddings = OllamaEmbeddings(
   model = "nomic-embed-text"
)

# %%
vectors = embeddings.embed_documents(
    chunks
)

# %%
print(vectors)
print(len(vectors))
print(len(chunks))
